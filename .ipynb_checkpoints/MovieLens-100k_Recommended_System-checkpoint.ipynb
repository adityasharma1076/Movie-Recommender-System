# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
user_colums = ['user id','age','gender','occupation','zip code']     ## For u.user file in movielens-100k dataset
rating_coulmns = ['user id','movie id','rating','timestamp']          ## For u.data file in movielens-100k dataset

# %%
user_items =  "movie id | movie title | release date | video release date | IMDb URL | unknown | Action | Adventure | Animation | Children's | Comedy | Crime | Documentary | Drama | Fantasy | Film-Noir | Horror | Musical | Mystery | Romance | Sci-Fi | Thriller | War | Western"
user_columns = user_items.split(' | ')                               ## For u.item file in movielens-100k dataset

# %%
user_columns
# Out:
# ['movie id',
#  'movie title',
#  'release date',
#  'video release date',
#  'IMDb URL',
#  'unknown',
#  'Action',
#  'Adventure',
#  'Animation',
#  "Children's",
#  'Comedy',
#  'Crime',
#  'Documentary',
#  'Drama',
#  'Fantasy',
#  'Film-Noir',
#  'Horror',
#  'Musical',
#  'Mystery',
#  'Romance',
#  'Sci-Fi',
#  'Thriller',
#  'War',
#  'Western']

# %%
pd.read_csv
